# %%
import pandas as pd 
import numpy as np 
from bertopic import BERTopic 
import os
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer
import joblib
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_dropna = pd.read_csv('D:/abstract/wos_0531/bib_360446/dropna_abstract_334765.csv', engine='python')

# %%
df_dropna
# Out:
#        Publication Type                                            Authors  \
# 0                     J                                 Soldo, A; Bakiu, R
# 1                     J                               Fetahu, E; Yilmaz, O
# 2                     J  Crocetta, F; Al Mabruk, SAA; Azzurro, E; Bakiu...
# 3                     J  Tsagarakis, K; Agius Darmanin, S; Al Mabruk, S...
# 4                     J           Pagano, M; Stara, A; Aliko, V; Faggio, C
# ...                 ...                                                ...
# 334760                J               Gwenzi, W; Chinyama, SR; Togarepi, S
# 334761                J  Wuta, M; Nyamadzawo, G; Mlambo, J; Nyamugafata, P
# 334762                J            Maguranyanga, C; Murwira, A; Sibanda, M
# 334763                J                           Manatsa, D; Matarira, CH
# 334764                J  Manatsa, D; Chingombe, W; Matsikwa, H; Matarir...
#
#        Book Authors Book Editors Book Group Authors  \
# ...

# %%
df_label = pd.read_csv('D:/abstract/wos_0531/bib_360446/unique_multilabel_withlabel.csv', engine='python')

# %%
data_dir = 'D:/abstract/climate change/all_inter.csv'
df_inter = pd.read_csv(data_dir, engine='python')

# %%
df_label
# Out:
#                                                  Abstract  topic  \
# 0       This paper presents an updated checklist of ma...     13
# 1       Small time behavior of gravity driven free sur...     16
# 2       This Collective Article includes records of 29...     13
# 3       This Collective Article presents information a...     13
# 4       The use of pesticides in agriculture has alway...     73
# ...                                                   ...    ...
# 334760  The simplicity of the hydrochemical stationari...     40
# 334761  In many smallholder farms in sub-Saharan Afric...     40
# 334762  In this study we tested whether we can use a t...      0
# 334763  A novel approach of using variability as a maj...     69
# 334764  The dominant climatic mode responsible for sea...     26
#
#                                            Research Areas  \
# 0               Marine & Freshwater Biology; Oceanography
# 1                               Engineering; Oceanography
# ...

# %%
abstract = list(df_label['Abstract'])

# %%
indexes = list(df_label['index'])

# %%
df_label['UT (Unique WOS ID)']=df_dropna['UT (Unique WOS ID)']

# %%
ut = list(df_label['UT (Unique WOS ID)'])

# %%
df_inter
# Out:
#        Unnamed: 0.1  Unnamed: 0 Publication Type  \
# 0                 0          15                J
# 1                 1          24                J
# 2                 2          37                J
# 3                 3          39                J
# 4                 4          42                J
# ...             ...         ...              ...
# 52211         52211      471141                J
# 52212         52212      471158                J
# 52213         52213      471180                J
# 52214         52214      471193                J
# 52215         52215      471228                J
#
#                                                  Authors Book Authors  \
# 0                        Seidov, D; Barron, E; Haupt, BJ          NaN
# 1         Stephens, C; Levitus, S; Antonov, J; Boyer, TP          NaN
# 2      Vink, A; Ruhlemann, C; Zonneveld, KAF; Mulitza...          NaN
# 3                                        Wang, B; An, SI          NaN
# ...

# %%
labels = []
ut_inter = list(df_inter['UT (Unique WOS ID)'])
for i in range(52216):
    ab = ut_inter[i]
    label = indexes[ut.index(ab)]
    labels.append(label)

# %%
ut_inter
# Out:
# ['WOS:000171217300025']

# %%
labels
# Out:
# [4,
#  4,
#  4,
#  4,
#  4,
#  6,
#  1,
#  1,
#  1,
#  4,
#  4,
#  3,
#  1,
#  4,
#  4,
#  4,
#  4,
#  0,
#  0,
#  4,
#  1,
#  4,
#  4,
#  3,
#  1,
#  3,
#  4,
#  4,
#  4,
#  1,
#  4,
#  1,
#  2,
#  6,
#  4,
#  4,
#  4,
#  3,
#  4,
#  5,
#  6,
#  4,
#  1,
#  1,
#  4,
#  1,
#  1,
#  4,
#  1,
#  1,
#  4,
#  6,
#  4,
#  4,
#  1,
#  1,
#  1,
#  0,
#  0,
#  1,
#  4,
#  1,
#  1,
#  0,
#  0,
#  1,
#  1,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  3,
#  1,
#  4,
#  4,
#  1,
#  3,
#  6,
#  3,
#  4,
#  3,
#  1,
#  1,
#  4,
#  4,
#  3,
#  0,
#  3,
#  2,
#  2,
#  4,
#  2,
#  1,
#  1,
#  1,
#  1,
#  4,
#  3,
#  1,
#  1,
#  1,
#  4,
#  0,
#  2,
#  3,
#  4,
#  1,
#  1,
#  4,
#  4,
#  4,
#  3,
#  6,
#  4,
#  6,
#  0,
#  0,
#  4,
#  4,
#  3,
#  4,
#  1,
#  1,
#  1,
#  2,
#  1,
#  4,
#  1,
#  1,
#  1,
#  1,
#  4,
#  4,
#  1,
#  3,
#  4,
#  4,
#  3,
#  1,
#  4,
#  4,
#  1,
#  1,
#  4,
#  6,
#  1,
#  1,
#  0,
#  0,
#  1,
#  0,
#  0,
#  3,
#  1,
#  4,
#  1,
#  1,
#  1,
#  4,
#  0,
#  1,
#  3,
# ...

# %%
df_inter['label'] = labels

# %%
df_inter.to_csv('D:/abstract/climate change/all_inter_withlabel.csv', index=False)
